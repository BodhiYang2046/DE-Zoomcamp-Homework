# %%
import pandas as pd
from time import time
from sqlalchemy import create_engine

# %%
df = pd.read_csv('green_tripdata_2019-09.csv', low_memory=False)

# %%
df['lpep_pickup_datetime'] = df['lpep_pickup_datetime'].apply(lambda x:x[:10])
df['lpep_dropoff_datetime'] = df['lpep_dropoff_datetime'].apply(lambda x:x[:10])

# %%
df[(df['lpep_pickup_datetime']=='2019-09-18') & (df['lpep_dropoff_datetime']=='2019-09-18')]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 217634       2.0           2019-09-18            2019-09-18
# 218133       2.0           2019-09-18            2019-09-18
# 218134       2.0           2019-09-18            2019-09-18
# 218254       2.0           2019-09-18            2019-09-18
# 218281       2.0           2019-09-18            2019-09-18
# ...          ...                  ...                   ...
# 423824       NaN           2019-09-18            2019-09-18
# 423825       NaN           2019-09-18            2019-09-18
# 423828       NaN           2019-09-18            2019-09-18
# 423830       NaN           2019-09-18            2019-09-18
# 423831       NaN           2019-09-18            2019-09-18
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 217634                  N         1.0            95           134
# 218133                  N         1.0            95           196
# ...

# %%
df.trip_distance.max()
# Out:
# 341.64

# %%
df[df.trip_distance==341.64]
# Out:
#         VendorID lpep_pickup_datetime lpep_dropoff_datetime  \
# 337292       2.0           2019-09-26            2019-09-27
#
#        store_and_fwd_flag  RatecodeID  PULocationID  DOLocationID  \
# 337292                  N         4.0           265            16
#
#         passenger_count  trip_distance  fare_amount  extra  mta_tax  \
# 337292              1.0         341.64       1761.0    1.0      0.5
#
#         tip_amount  tolls_amount  ehail_fee  improvement_surcharge  \
# 337292         0.0           0.0        NaN                    0.3
#
#         total_amount  payment_type  trip_type  congestion_surcharge
# 337292        1762.8           2.0        1.0                   0.0

# %%
df1 = pd.read_csv('taxi+_zone_lookup.csv')

# %%
df1
# Out:
#      LocationID        Borough                     Zone service_zone
# 0             1            EWR           Newark Airport          EWR
# 1             2         Queens              Jamaica Bay    Boro Zone
# 2             3          Bronx  Allerton/Pelham Gardens    Boro Zone
# 3             4      Manhattan            Alphabet City  Yellow Zone
# 4             5  Staten Island            Arden Heights    Boro Zone
# ..          ...            ...                      ...          ...
# 260         261      Manhattan       World Trade Center  Yellow Zone
# 261         262      Manhattan           Yorkville East  Yellow Zone
# 262         263      Manhattan           Yorkville West  Yellow Zone
# 263         264        Unknown                       NV          NaN
# 264         265        Unknown                      NaN          NaN
#
# [265 rows x 4 columns]

# %%
df1.Borough.value_counts()
# Out:
# Queens           69
# Manhattan        69
# Brooklyn         61
# Bronx            43
# Staten Island    20
# Unknown           2
# EWR               1
# Name: Borough, dtype: int64

# %%
df1[df1.Zone=='Astoria']
# Out:
#    LocationID Borough     Zone service_zone
# 6           7  Queens  Astoria    Boro Zone

# %%
df = df.merge(df1[['LocationID', 'Zone']], left_on='PULocationID', right_on='LocationID', \
         how='left').merge(df1[['LocationID', 'Zone']], left_on='DOLocationID', \
                           right_on='LocationID', how='left')

# %%
df[df['Zone_x']=='Astoria'].tip_amount.max()
# Out:
# 62.31

# %%
df[(df['Zone_x']=='Astoria') & (df['tip_amount']==62.31)].Zone_y
# Out:
# 98185    JFK Airport
# Name: Zone_y, dtype: object

# %%
df.columns.tolist()
# Out:
# ['VendorID',
#  'lpep_pickup_datetime',
#  'lpep_dropoff_datetime',
#  'store_and_fwd_flag',
#  'RatecodeID',
#  'PULocationID',
#  'DOLocationID',
#  'passenger_count',
#  'trip_distance',
#  'fare_amount',
#  'extra',
#  'mta_tax',
#  'tip_amount',
#  'tolls_amount',
#  'ehail_fee',
#  'improvement_surcharge',
#  'total_amount',
#  'payment_type',
#  'trip_type',
#  'congestion_surcharge',
#  'LocationID_x',
#  'Zone_x',
#  'LocationID_y',
#  'Zone_y']
